# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import time
from spikingjelly.activation_based import neuron, functional, layer

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Current device: {torch.cuda.get_device_name(0)}")
    print(f"Device count: {torch.cuda.device_count()}") # 应该输出 1
# Out:
# PyTorch version: 2.9.1+cu128
# CUDA available: True
# Current device: NVIDIA GeForce RTX 3090
# Device count: 1

# %%
import psutil
import os

# 获取当前进程内存使用
process = psutil.Process(os.getpid())
memory_info = process.memory_info()
print(f"当前Python进程内存使用: {memory_info.rss / 1024 / 1024:.2f} MB")

# 获取系统总内存信息
memory = psutil.virtual_memory()
print(f"总内存: {memory.total / 1024 / 1024 / 1024:.2f} GB")
print(f"已使用: {memory.used / 1024 / 1024 / 1024:.2f} GB")
print(f"可用内存: {memory.available / 1024 / 1024 / 1024:.2f} GB")
print(f"内存使用率: {memory.percent}%")
# Out:
# 当前Python进程内存使用: 697.78 MB
# 总内存: 251.56 GB
# 已使用: 12.22 GB
# 可用内存: 237.44 GB
# 内存使用率: 5.6%

# %%
import tonic

# 设置保存路径为当前目录（根目录）
# tonic 会自动在 './' 下创建一个名为 'CIFAR10DVS' 的文件夹来存放数据
save_path = './' 

print(f"开始下载 CIFAR10-DVS 数据集到路径: {save_path}CIFAR10DVS/")
print("这可能需要一段时间，请耐心等待...")


dataset = tonic.datasets.CIFAR10DVS(
    save_to=save_path
)

print("\n 数据集下载并解压完成。")
print(f"数据集位于: {save_path}CIFAR10DVS/")

# 验证数据集是否可用
# 打印训练集第一个样本的路径，用于确认数据结构
first_sample_path = dataset.data[0][0]
print(f"第一个样本文件路径 (例如): {first_sample_path}")
# Out:
# 开始下载 CIFAR10-DVS 数据集到路径: ./CIFAR10DVS/
# 这可能需要一段时间，请耐心等待...
# ...
# 11168490496it [29:07, 6391178.41it/s]
# Extracting ./CIFAR10DVS/CIFAR10DVS.zip to ./CIFAR10DVS
#
# ✅ 数据集下载并解压完成。
# 数据集位于: ./CIFAR10DVS/
# 第一个样本文件路径 (例如): .
